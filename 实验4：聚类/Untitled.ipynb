# %%
import math
import operator
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data_set=pd.read_csv("C:/Users/MY/Desktop/数据挖掘实验/实验4：聚类/WorldCup.csv",engine="python")
data_list=data_set.values.tolist()

# %%
for i in range(2):
    clust1=[] #簇1
    print(clust1)
    
    clust1.append(1)
    print(clust1)
# Out:
# []
# [1]
# []
# [1]

# %%
#先随机挑选3个中心点,(我这里是指定)
cluster_centers=[data_list[3],data_list[5],data_list[14]] #初始的三个中心点
#print(cluster_centers[0])

#先把中心点排除: 
copy_data_list=copy.copy(data_list)
for n in range(3):
    #print(cluster_centers[n][0])
    copy_data_list.pop(cluster_centers[n][0])

count=0
#把所有非中心点拿来分别替换c1,c2,c3
for center_idx in range(3): #每次换一个中心点
    #print(center)
    for country in copy_data_list:
        #print(country)
        cluster_centers[center_idx]=country #
        print(cluster_centers)
        count+=1
print(count)
# Out:
# [[0, '中国', 73, 40, 7], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[1, '日本', 60, 15, 5], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[2, '韩国', 61, 19, 2], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[4, '沙特', 67, 26, 10], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[5, '伊拉克', 91, 40, 4], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[7, '阿联酋', 81, 40, 6], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[8, '乌兹别克斯坦', 88, 40, 6], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[9, '泰国', 122, 40, 17], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[10, '越南', 102, 50, 17], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[11, '阿曼', 87, 50, 17], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[12, '巴林', 116, 50, 11], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[13, '朝鲜', 110, 50, 14], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[14, '印尼', 164, 50, 17], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[15, '澳洲', 40, 30, 1], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[17, '约旦', 118, 50, 9], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[18, '科威特', 160, 50, 15], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[19, '巴勒斯坦', 96, 50, 16], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[19, '巴勒斯坦', 96, 50, 16], [0, '中国', 73, 40, 7], [14, '印尼', 164, 50, 17]]
# [[19, '巴勒斯坦', 96, 50, 16], [1, '日本', 60, 15, 5], [14, '印尼', 164, 50, 17]]
# [[19, '巴勒斯坦', 96, 50, 16], [2, '韩国', 61, 19, 2], [14, '印尼', 164, 50, 17]]
# [[19, '巴勒斯坦', 96, 50, 16], [4, '沙特', 67, 26, 10], [14, '印尼', 164, 50, 17]]
# [[19, '巴勒斯坦', 96, 50, 16], [5, '伊拉克', 91, 40, 4], [14, '印尼', 164, 50, 17]]
# [[19, '巴勒斯坦', 96, 50, 16], [7, '阿联酋', 81, 40, 6], [14, '印尼', 164, 50, 17]]
